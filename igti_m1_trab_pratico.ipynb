# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasLCarreira/IGTI_BOOTCAMP_DADOS/blob/master/igti_m1_trab_pratico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Módulo 1 - Trabalho prático

# %% [markdown]
# 1. Considere o dataset gerado a partir das instruções do enunciado. Caso o algoritmo seja executado buscando apenas 1 cluster, qual será a soma dos quadrados intra-clusters (wcss) ao final da execução?

# %% [markdown]
# Importação das bibliotecas

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
X, y = make_blobs(n_samples=500, centers=20, random_state=999)
plt.scatter(X[:,0], X[:,1])

# %%
kmeans = KMeans(n_clusters=1, init='k-means++', max_iter=300, n_init=10)
kmeans.fit(X)
WCSS = (kmeans.inertia_)
plt.plot(WCSS)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
print(WCSS)
# Out:
# 31547.372471390485

# %%
WCSS = []
for i in range(1, 20):
  kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10)
  kmeans.fit(X)
  WCSS.append(kmeans.inertia_)
plt.plot(range(1, 20), WCSS)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
print(WCSS[4])
# Out:
# 4717.404091931214

# %%
kmeans = KMeans(n_clusters=4, init='k-means++', max_iter=300, n_init=10, random_state=0)
pred_y = kmeans.fit_predict(X)
plt.scatter(X[:,0], X[:,1], c=pred_y)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=50, c='red')
plt.show()
centers = kmeans.cluster_centers_
centers
# Out:
# array([[ 6.07279058, -8.8012785 ],
#        [ 4.6799272 ,  1.81951975],
#        [-6.10635026, -3.5270784 ],
#        [-4.18061418,  4.39438299]])

# %%
kmeans = KMeans(n_clusters=1, init='k-means++', max_iter=300, n_init=10, random_state=0)
pred_y = kmeans.fit_predict(X)
plt.scatter(X[:,0], X[:,1], c=pred_y)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=50, c='red')
plt.show()

# %%
centers = kmeans.cluster_centers_
centers
# Out:
# array([[ 0.02618523, -1.30384304]])
